# %%
import requests, uuid, time
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse, urlunparse
import pandas as pd

headers = {"User-Agent": "Mozilla/5.0"}

# ✅ Tambah kategori supaya data lebih banyak
category_urls = {
    "Nasional": "https://nasional.kompas.com/",
    "Ekonomi": "https://money.kompas.com/",
    "Tekno": "https://tekno.kompas.com/",
    "Otomotif": "https://otomotif.kompas.com/",
    "Health": "https://health.kompas.com/",
    "Edukasi": "https://edukasi.kompas.com/",
    "Bola": "https://bola.kompas.com/",
    "Entertainment": "https://entertainment.kompas.com/",
    "Lifestyle": "https://lifestyle.kompas.com/",
    "Travel": "https://travel.kompas.com/",
    "Internasional": "https://internasional.kompas.com/",
    "Properti": "https://properti.kompas.com/",
    "Sains": "https://sains.kompas.com/"
}

def canonicalize(url):
    p = urlparse(url)
    return urlunparse((p.scheme or "https", p.netloc, p.path.rstrip('/'), "", "", ""))

def first_text(soup, selectors):
    for sel in selectors:
        nodes = soup.select(sel)
        if nodes:
            return " ".join([n.get_text(strip=True) for n in nodes])
    return None

seen_urls = set()

def parse_news_detail(url, default_category):
    try:
        res = requests.get(url, headers=headers, timeout=10)
        if res.status_code != 200:
            print(f"[ERROR] status {res.status_code} for {url}")
            return None
        soup = BeautifulSoup(res.text, "html.parser")

        # canonical URL
        canon_tag = soup.select_one('link[rel="canonical"]')
        final_url = canon_tag['href'] if canon_tag and canon_tag.get('href') else res.url
        url_key = canonicalize(final_url)
        if url_key in seen_urls:
            return None
        seen_urls.add(url_key)

        # judul
        title = first_text(soup, ["h1.read__title", "h1.article__title", "h1.title"])
        if not title:
            m = soup.find('meta', property='og:title') or soup.find('meta', attrs={'name': 'title'})
            title = m['content'] if m and m.get('content') else ""

        # isi
        content = first_text(soup, [
            "div.read__content p",
            "div.article__content p",
            "div.detail_text p",
            "div.article__lead p",
            "div._article_content p"
        ])
        if not content:
            m = soup.find('meta', property='og:description') or soup.find('meta', attrs={'name': 'description'})
            content = m['content'] if m and m.get('content') else ""

        # kategori (pakai kategori input biar konsisten)
        breadcrumb = [a.get_text(strip=True) for a in soup.select("a.breadcrumb__link, span.breadcrumb__link")]
        detected_kategori = breadcrumb[-1] if breadcrumb else default_category

        return {
            "id": str(uuid.uuid4()),
            "judul": title,
            "isi": content,
            "kategori": default_category,           # konsisten
            "detected_kategori": detected_kategori, # info tambahan
            "url": final_url
        }
    except Exception as e:
        print(f"[ERROR parsing] {url}: {e}")
        return None

def crawl_category(name, base_url, max_news_per_page=None, max_pages=20):
    print(f"[CRAWL] {name} — {base_url}")
    news_list = []
    page = 1
    while True:
        if max_pages and page > max_pages:
            break
        page_url = f"{base_url}?page={page}"
        print(f"  [PAGE {page}] {page_url}")
        res = requests.get(page_url, headers=headers, timeout=10)
        if res.status_code != 200:
            print(f"   [ERROR] Can't access {page_url}")
            break
        soup = BeautifulSoup(res.text, "html.parser")

        # ambil semua link berita
        anchors = soup.select("h3.article__title a, h4.article__title a, article a")
        if not anchors:
            print("   [INFO] No links found, stop.")
            break

        # filter & canonicalize
        hrefs = []
        for a in anchors:
            href = a.get("href")
            if not href:
                continue
            full = urljoin(base_url, href)
            key = canonicalize(full)
            if key not in seen_urls and key not in hrefs:
                hrefs.append(full)

        print(f"   → Found {len(hrefs)} unique links on page {page}")

        for idx, link in enumerate(hrefs):
            if max_news_per_page and idx >= max_news_per_page:
                break
            print(f"     - Fetching {idx+1}: {link}")
            news = parse_news_detail(link, name)
            if news:
                news_list.append(news)
            time.sleep(1)

        page += 1
    return news_list

if __name__ == "__main__":
    hasil = []
    for kategori, url in category_urls.items():
        hasil.extend(crawl_category(kategori, url, max_news_per_page=None, max_pages=20))  # ambil lebih banyak

    df = pd.DataFrame(hasil)
    df = df.drop_duplicates(subset=['url'])
    df.to_csv("kompas_news_big.csv", index=False, encoding="utf-8-sig")
    print(f"[DONE] Total {len(df)} berita disimpan ke kompas_news_big.csv")
# Out:
# [CRAWL] Nasional — https://nasional.kompas.com/
#   [PAGE 1] https://nasional.kompas.com/?page=1
#    [INFO] No links found, stop.
# [CRAWL] Ekonomi — https://money.kompas.com/
#   [PAGE 1] https://money.kompas.com/?page=1
#    → Found 1 unique links on page 1
#      - Fetching 1: https://video.kompas.com/watch/1873974/cara-klaim-diskon-tambah-daya-listrik-pln-50-persen-september-2025?source=KOMPASCOM&position=money_terkini__player_1
#   [PAGE 2] https://money.kompas.com/?page=2
#    → Found 0 unique links on page 2
#   [PAGE 3] https://money.kompas.com/?page=3
#    → Found 0 unique links on page 3
#   [PAGE 4] https://money.kompas.com/?page=4
#    → Found 0 unique links on page 4
#   [PAGE 5] https://money.kompas.com/?page=5
#    → Found 0 unique links on page 5
#   [PAGE 6] https://money.kompas.com/?page=6
#    → Found 0 unique links on page 6
#   [PAGE 7] https://money.kompas.com/?page=7
#    → Found 0 unique links on page 7
#   [PAGE 8] https://money.kompas.com/?page=8
#    → Found 0 unique links on page 8
#   [PAGE 9] https://money.kompas.com/?page=9
#    → Found 0 unique links on page 9
#   [PAGE 10] https://money.kompas.com/?page=10
#    → Found 0 unique links on page 10
#   [PAGE 11] https://money.kompas.com/?page=11
#    → Found 0 unique links on page 11
#   [PAGE 12] https://money.kompas.com/?page=12
#    → Found 0 unique links on page 12
#   [PAGE 13] https://money.kompas.com/?page=13
#    → Found 0 unique links on page 13
#   [PAGE 14] https://money.kompas.com/?page=14
#    → Found 0 unique links on page 14
#   [PAGE 15] https://money.kompas.com/?page=15
#    → Found 0 unique links on page 15
#   [PAGE 16] https://money.kompas.com/?page=16
#    → Found 0 unique links on page 16
#   [PAGE 17] https://money.kompas.com/?page=17
#    → Found 0 unique links on page 17
#   [PAGE 18] https://money.kompas.com/?page=18
#    → Found 0 unique links on page 18
#   [PAGE 19] https://money.kompas.com/?page=19
#    → Found 0 unique links on page 19
#   [PAGE 20] https://money.kompas.com/?page=20
#    → Found 0 unique links on page 20
# [CRAWL] Tekno — https://tekno.kompas.com/
#   [PAGE 1] https://tekno.kompas.com/?page=1
#    → Found 29 unique links on page 1
#      - Fetching 1: https://tekno.kompas.com/read/2025/09/10/19080037/oppo-a6i-meluncur-hp-murah-dengan-material-kuat-dan-baterai-besar-
http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 28: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 29: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 2] https://tekno.kompas.com/?page=2
#    → Found 6 unique links on page 2
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 3] https://tekno.kompas.com/?page=3
#    → Found 6 unique links on page 3
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 4] https://tekno.kompas.com/?page=4
#    → Found 6 unique links on page 4
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 5] https://tekno.kompas.com/?page=5
#    → Found 6 unique links on page 5
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 6] https://tekno.kompas.com/?page=6
#    → Found 6 unique links on page 6
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 7] https://tekno.kompas.com/?page=7
#    → Found 6 unique links on page 7
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 8] https://tekno.kompas.com/?page=8
#    → Found 6 unique links on page 8
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 9] https://tekno.kompas.com/?page=9
#    → Found 6 unique links on page 9
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 10] https://tekno.kompas.com/?page=10
#    → Found 6 unique links on page 10
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 11] https://tekno.kompas.com/?page=11
#    → Found 6 unique links on page 11
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 12] https://tekno.kompas.com/?page=12
#    → Found 6 unique links on page 12
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 13] https://tekno.kompas.com/?page=13
#    → Found 6 unique links on page 13
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 14] https://tekno.kompas.com/?page=14
#    → Found 6 unique links on page 14
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 15] https://tekno.kompas.com/?page=15
#    → Found 6 unique links on page 15
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 16] https://tekno.kompas.com/?page=16
#    → Found 6 unique links on page 16
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 17] https://tekno.kompas.com/?page=17
#    → Found 6 unique links on page 17
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 18] https://tekno.kompas.com/?page=18
#    → Found 6 unique links on page 18
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 19] https://tekno.kompas.com/?page=19
#    → Found 6 unique links on page 19
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
#   [PAGE 20] https://tekno.kompas.com/?page=20
#    → Found 6 unique links on page 20
#      - Fetching 1: http://tekno.kompas.com/read/2025/09/10/08030077/lenovo-rilis-monitor-5k-lengkung-hemat-daya-thinkvision-p40wd
#      - Fetching 2: http://tekno.kompas.com/read/2025/09/09/16420027/lenovo-rilis-flicklift-edit-foto-di-laptop-tak-perlu-photoshop
#      - Fetching 3: http://tekno.kompas.com/read/2025/09/09/16080017/lenovo-rilis-loq-tower-26adr10-pc-gaming-dengan-panel-transparan-dan-futuristik
#      - Fetching 4: http://tekno.kompas.com/read/2025/09/01/16020047/hands-on-infinix-hot-60-pro-plus--enteng-tipis-seperti-tak-bawa-hp
#      - Fetching 5: http://tekno.kompas.com/read/2025/09/01/13310097/buka-kotak-samsung-galaxy-a17-5g-hp-ai-rp-3-jutaan
#      - Fetching 6: http://tekno.kompas.com/read/2025/08/30/16020047/mencoba-saramonic-air-microfon-wireless-ringkas-dan-murah-untuk-kreator-konten
# [CRAWL] Otomotif — https://otomotif.kompas.com/
#   [PAGE 1] https://otomotif.kompas.com/?page=1
#    → Found 28 unique links on page 1
#      - Fetching 1: https://otomotif.kompas.com/read/2025/09/10/201648315/edukasi-perlindungan-kendaraan-menggunakan-asuransi-buat-konsumen
#      - Fetching 2: https://otomotif.kompas.com/read/2025/09/10/192100615/farizon-merek-baru-asal-china-masuk-indonesia-gandeng-arista
#      - Fetching 24: https://otomotif.kompas.com/read/2025/09/10/152100115/simak-harga-bekas-daihatsu-xenia-tahun-muda
#      - Fetching 25: https://otomotif.kompas.com/read/2025/09/10/151200615/skema-cicilan-lcgc-bekas--per-bulan-mulai-rp-1-jutaan
#      - Fetching 26: https://otomotif.kompas.com/read/2025/09/10/150100215/mercedes-benz-perkenalkan-glc-eq-di-munich-motor-show-2025
#      - Fetching 27: https://otomotif.kompas.com/read/2025/09/10/144100815/penjualan-motor-januari-agustus-2025-tembus-4-2-juta-unit
#      - Fetching 28: https://otomotif.kompas.com/read/2025/09/10/142100415/suzuki-gsx-r-125-dan-gsx-s-125-diskontinu-bagaimana-di-indonesia-
#   [PAGE 2] https://otomotif.kompas.com/?page=2
#    → Found 0 unique links on page 2
#   [PAGE 3] https://otomotif.kompas.com/?page=3
#    → Found 0 unique links on page 3
#   [PAGE 4] https://otomotif.kompas.com/?page=4
#    → Found 0 unique links on page 4
#   [PAGE 5] https://otomotif.kompas.com/?page=5
#    → Found 0 unique links on page 5
#   [PAGE 6] https://otomotif.kompas.com/?page=6
#    → Found 0 unique links on page 6
#   [PAGE 7] https://otomotif.kompas.com/?page=7
#    → Found 0 unique links on page 7
#   [PAGE 8] https://otomotif.kompas.com/?page=8
#    → Found 0 unique links on page 8
#   [PAGE 9] https://otomotif.kompas.com/?page=9
#    → Found 0 unique links on page 9
#   [PAGE 10] https://otomotif.kompas.com/?page=10
#    → Found 0 unique links on page 10
#   [PAGE 11] https://otomotif.kompas.com/?page=11
#    → Found 0 unique links on page 11
#   [PAGE 12] https://otomotif.kompas.com/?page=12
#    → Found 0 unique links on page 12
#   [PAGE 13] https://otomotif.kompas.com/?page=13
#    → Found 0 unique links on page 13
#   [PAGE 14] https://otomotif.kompas.com/?page=14
#    → Found 0 unique links on page 14
#   [PAGE 15] https://otomotif.kompas.com/?page=15
#    → Found 0 unique links on page 15
#   [PAGE 16] https://otomotif.kompas.com/?page=16
#    → Found 0 unique links on page 16
#   [PAGE 17] https://otomotif.kompas.com/?page=17
#    → Found 0 unique links on page 17
#   [PAGE 18] https://otomotif.kompas.com/?page=18
#    → Found 0 unique links on page 18
#   [PAGE 19] https://otomotif.kompas.com/?page=19
#    → Found 0 unique links on page 19
#   [PAGE 20] https://otomotif.kompas.com/?page=20
#    → Found 0 unique links on page 20
# [CRAWL] Health — https://health.kompas.com/
#   [PAGE 1] https://health.kompas.com/?page=1
#    [INFO] No links found, stop.
# [CRAWL] Edukasi — https://edukasi.kompas.com/
#   [PAGE 1] https://edukasi.kompas.com/?page=1
#    [INFO] No links found, stop.
# [CRAWL] Bola — https://bola.kompas.com/
#   [PAGE 1] https://bola.kompas.com/?page=1
#    → Found 23 unique links on page 1
#      - Fetching 1: https://bola.kompas.com/read/2025/09/10/22534188/manuel-neuer-tolak-pensiun-di-usia-39-tahun-siap-comeback-ke-timnas-jerman
#      - Fetching 2: https://bola.kompas.com/read/2025/09/10/22383378/man-city-vs-man-united-citizens-kehilangan-satu-penyerang-di-derbi-manchester
#    → Found 0 unique links on page 2
#   [PAGE 3] https://bola.kompas.com/?page=3
#    → Found 0 unique links on page 3
#   [PAGE 4] https://bola.kompas.com/?page=4
#    → Found 0 unique links on page 4
#   [PAGE 5] https://bola.kompas.com/?page=5
#    → Found 0 unique links on page 5
#   [PAGE 6] https://bola.kompas.com/?page=6
#    → Found 0 unique links on page 6
#   [PAGE 7] https://bola.kompas.com/?page=7
#    → Found 0 unique links on page 7
#   [PAGE 8] https://bola.kompas.com/?page=8
#    → Found 0 unique links on page 8
#   [PAGE 9] https://bola.kompas.com/?page=9
#    → Found 0 unique links on page 9
#   [PAGE 10] https://bola.kompas.com/?page=10
#    → Found 0 unique links on page 10
#   [PAGE 11] https://bola.kompas.com/?page=11
#    → Found 0 unique links on page 11
#   [PAGE 12] https://bola.kompas.com/?page=12
#    → Found 0 unique links on page 12
#   [PAGE 13] https://bola.kompas.com/?page=13
#    → Found 0 unique links on page 13
#   [PAGE 14] https://bola.kompas.com/?page=14
#    → Found 0 unique links on page 14
#   [PAGE 15] https://bola.kompas.com/?page=15
#    → Found 0 unique links on page 15
#   [PAGE 16] https://bola.kompas.com/?page=16
#    → Found 0 unique links on page 16
#   [PAGE 17] https://bola.kompas.com/?page=17
#    → Found 0 unique links on page 17
#   [PAGE 18] https://bola.kompas.com/?page=18
#    → Found 0 unique links on page 18
#   [PAGE 19] https://bola.kompas.com/?page=19
#    → Found 0 unique links on page 19
#   [PAGE 20] https://bola.kompas.com/?page=20
#    → Found 0 unique links on page 20
# [CRAWL] Entertainment — https://entertainment.kompas.com/
#   [PAGE 1] https://entertainment.kompas.com/?page=1
#    → Found 5 unique links on page 1
#      - Fetching 1: https://entertainment.kompas.com/read/2025/09/07/235615366/usai-ketahuan-selingkuh-di-konser-coldplay-kristin-cabot-ajukan
#      - Fetching 2: https://entertainment.kompas.com/read/2025/09/07/152345266/nandi-juliawan-encuy-meninggal-kang-cecep-satu-lagi-sahabat-pergi-di
#      - Fetching 3: https://entertainment.kompas.com/read/2025/09/01/152541066/drakor-bon-appetit-your-majesty-berapa-episode
#      - Fetching 4: https://entertainment.kompas.com/read/2025/08/29/180000766/sertakan-emoji-mawar-layu-duta-sheila-on-7-doakan-affan-kurniawan
#      - Fetching 5: https://entertainment.kompas.com/read/2025/08/29/112526766/viral-joget-di-dpr-uya-kuya-saya-minta-maaf-tidak-maksud-meledek
#   [PAGE 2] https://entertainment.kompas.com/?page=2
#    → Found 0 unique links on page 2
#   [PAGE 3] https://entertainment.kompas.com/?page=3
#    → Found 0 unique links on page 3
#   [PAGE 4] https://entertainment.kompas.com/?page=4
#    → Found 0 unique links on page 4
#   [PAGE 5] https://entertainment.kompas.com/?page=5
#    → Found 0 unique links on page 5
#   [PAGE 6] https://entertainment.kompas.com/?page=6
#    → Found 0 unique links on page 6
#   [PAGE 7] https://entertainment.kompas.com/?page=7
#    → Found 0 unique links on page 7
#   [PAGE 8] https://entertainment.kompas.com/?page=8
#    → Found 0 unique links on page 8
#   [PAGE 9] https://entertainment.kompas.com/?page=9
#    → Found 0 unique links on page 9
#   [PAGE 10] https://entertainment.kompas.com/?page=10
#    → Found 0 unique links on page 10
#   [PAGE 11] https://entertainment.kompas.com/?page=11
#    → Found 0 unique links on page 11
#   [PAGE 12] https://entertainment.kompas.com/?page=12
#    → Found 0 unique links on page 12
#   [PAGE 13] https://entertainment.kompas.com/?page=13
#    → Found 0 unique links on page 13
#   [PAGE 14] https://entertainment.kompas.com/?page=14
#    → Found 0 unique links on page 14
#   [PAGE 15] https://entertainment.kompas.com/?page=15
#    → Found 0 unique links on page 15
#   [PAGE 16] https://entertainment.kompas.com/?page=16
#    → Found 0 unique links on page 16
#   [PAGE 17] https://entertainment.kompas.com/?page=17
#    → Found 0 unique links on page 17
#   [PAGE 18] https://entertainment.kompas.com/?page=18
#    → Found 0 unique links on page 18
#   [PAGE 19] https://entertainment.kompas.com/?page=19
#    → Found 0 unique links on page 19
#   [PAGE 20] https://entertainment.kompas.com/?page=20
#    → Found 0 unique links on page 20
# [CRAWL] Lifestyle — https://lifestyle.kompas.com/
#   [PAGE 1] https://lifestyle.kompas.com/?page=1
#    [INFO] No links found, stop.
# [CRAWL] Travel — https://travel.kompas.com/
#   [PAGE 1] https://travel.kompas.com/?page=1
#    [INFO] No links found, stop.
# [CRAWL] Internasional — https://internasional.kompas.com/
#   [PAGE 1] https://internasional.kompas.com/?page=1
#    [INFO] No links found, stop.
# [CRAWL] Properti — https://properti.kompas.com/
#   [PAGE 1] https://properti.kompas.com/?page=1
#    → Found 20 unique links on page 1
#      - Fetching 1: https://www.kompas.com/properti/read/2025/09/10/230000421/curhat-transmigran-batu-ampar-mandi-di-sungai-hingga-minum-air-hujan
#      - Fetching 2: https://www.kompas.com/properti/read/2025/09/10/222113721/kawasan-it-center-bri-diakui-para-ahli-manajemen-konstruksi-ramping
#      - Fetching 3: https://www.kompas.com/properti/read/2025/09/10/212900921/kementerian-transmigrasi-kucurkan-rp-45-miliar-untuk-bengkulu-selatan
#      - Fetching 4: https://www.kompas.com/properti/read/2025/09/10/201938721/5-rekomendasi-rumah-murah-di-kota-banjarmasin-hanya-rp150-jutaan
#      - Fetching 5: https://properti.kompas.com/read/2025/09/10/183000021/cara-urus-surat-keterangan-bebas-pajak-waris-syarat-dan-lama-proses
#      - Fetching 6: https://www.kompas.com/properti/read/2025/09/10/180000121/pakai-lahan-pemprov-ara-berencana-bangun-rusun-subsidi-di-jakarta
#      - Fetching 7: https://www.kompas.com/properti/read/2025/09/10/165413621/ara-berencana-pulihkan-kawasan-kumuh-dan-sanitasi-di-jakarta
#      - Fetching 8: https://www.kompas.com/properti/read/2025/09/10/154457921/dukung-program-3-juta-rumah-dki-siapkan-19809-hunian
#      - Fetching 9: https://www.kompas.com/properti/read/2025/09/10/144651721/tol-permai-makin-ramai-dilintasi-65867-kendaraan-saat-libur-maulid-nabi
#      - Fetching 10: https://properti.kompas.com/read/2025/09/10/141351721/ketentuan-biaya-pajak-waris-saat-balik-nama-sertifikat-tanah-warisan
#      - Fetching 11: https://www.kompas.com/properti/read/2025/09/10/115707421/cilegon-tawarkan-berbagai-pilihan-rumah-subsidi-rp-140-jutaan
#      - Fetching 12: https://www.kompas.com/properti/read/2025/09/10/110000921/5-rumah-murah-di-kota-serang-dekat-jakarta-dan-hanya-rp130-jutaan
#      - Fetching 13: https://www.kompas.com/properti/read/2025/09/10/103000521/sulbar-bakal-punya-bendungan-pertamanya-tahun-2027
#      - Fetching 14: https://www.kompas.com/properti/read/2025/09/10/100039721/5-properti-termurah-yang-akan-dilelang-kpk-mulai-rp-163-juta-saja
#      - Fetching 15: https://www.kompas.com/properti/read/2025/09/10/091650521/sistem-kur-perumahan-disiapkan-kementerian-pkp-pastikan-beres-akhir
#      - Fetching 16: https://www.kompas.com/properti/read/2025/09/10/090928821/98-persen-bidang-tanah-di-indonesia-sudah-terdaftar-di-bpn
#      - Fetching 17: https://www.kompas.com/properti/read/2025/09/10/085606221/daftar-lima-properti-sitaan-termahal-yang-akan-dilelang-kpk
#      - Fetching 18: https://www.kompas.com/properti/read/2025/09/10/070842221/rehabilitasi-wisma-mpr-di-bandung-perlu-kajian-sejarah
#      - Fetching 19: https://www.kompas.com/properti/read/2025/09/10/060300021/bengkulu-dapat-anggaran-tambahan-bangun-jalan-hingga-sarana-air-bersih
#      - Fetching 20: https://www.kompas.com/properti/read/2025/09/09/234829221/renovasi-400000-rumah-di-daerah-tertinggal-jadi-prioritas
#   [PAGE 2] https://properti.kompas.com/?page=2
#    → Found 0 unique links on page 2
#   [PAGE 3] https://properti.kompas.com/?page=3
#    → Found 0 unique links on page 3
#   [PAGE 4] https://properti.kompas.com/?page=4
#    → Found 0 unique links on page 4
#   [PAGE 5] https://properti.kompas.com/?page=5
#    → Found 0 unique links on page 5
#   [PAGE 6] https://properti.kompas.com/?page=6
#    → Found 0 unique links on page 6
#   [PAGE 7] https://properti.kompas.com/?page=7
#    → Found 0 unique links on page 7
#   [PAGE 8] https://properti.kompas.com/?page=8
#    → Found 0 unique links on page 8
#   [PAGE 9] https://properti.kompas.com/?page=9
#    → Found 0 unique links on page 9
#   [PAGE 10] https://properti.kompas.com/?page=10
#    → Found 0 unique links on page 10
#   [PAGE 11] https://properti.kompas.com/?page=11
#    → Found 0 unique links on page 11
#   [PAGE 12] https://properti.kompas.com/?page=12
#    → Found 0 unique links on page 12
#   [PAGE 13] https://properti.kompas.com/?page=13
#    → Found 0 unique links on page 13
#   [PAGE 14] https://properti.kompas.com/?page=14
#    → Found 0 unique links on page 14
#   [PAGE 15] https://properti.kompas.com/?page=15
#    → Found 0 unique links on page 15
#   [PAGE 16] https://properti.kompas.com/?page=16
#    → Found 0 unique links on page 16
#   [PAGE 17] https://properti.kompas.com/?page=17
#    → Found 0 unique links on page 17
#   [PAGE 18] https://properti.kompas.com/?page=18
#    → Found 0 unique links on page 18
#   [PAGE 19] https://properti.kompas.com/?page=19
#    → Found 0 unique links on page 19
#   [PAGE 20] https://properti.kompas.com/?page=20
#    → Found 0 unique links on page 20
# [CRAWL] Sains — https://sains.kompas.com/
#   [PAGE 1] https://sains.kompas.com/?page=1
#    [INFO] No links found, stop.
# [DONE] Total 106 berita disimpan ke kompas_news_big.csv
